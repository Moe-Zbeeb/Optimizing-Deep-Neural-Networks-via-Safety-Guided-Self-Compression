# %%
import re
from collections import Counter

# Load the SST2 dataset from the local file
file_path = 'sst2_train.txt'  # Replace with the actual path to your local SST2 dataset

# Read the file and split it into labels and sentences
data = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        label, sentence = line.strip().split('\t')
        data.append((label, sentence))

# Check the first few samples to verify
print("Sample data:", data[:3])
# Out:
# Sample data: [('0', 'hide new secretions from the parental units'), ('0', 'contains no wit , only labored gags'), ('1', 'that loves its characters and communicates something rather beautiful about human nature')]

# %%
# Function to tokenize sentences using regex
def tokenize_sentence(sentence):
    return re.findall(r'\b\w+\b', sentence.lower())  # Convert to lowercase and tokenize

# Tokenize the sentences in the dataset
tokenized_data = [(label, tokenize_sentence(sentence)) for label, sentence in data]

# %%
# Flatten all tokenized sentences to get a list of all words
all_words = [word for _, sentence in tokenized_data for word in sentence]

# Compute word frequencies
word_freq = Counter(all_words)

# Define rare words as those appearing less than 2 times
rare_threshold = 2
rare_words = {word for word, count in word_freq.items() if count < rare_threshold}

print("Rare words:", rare_words)
# Out:
# Rare words: {'honks', 'lodge', 'nia', 'mingles', 'depalma', 'masseur', '1970', 'impressionable', 'subcultures', 'unrepentant', 'shut', 'strategy', 'duties', 'irreverence', 'command', 'mama', 'elfriede', 'cloaks', 'tyson', 'baio', 'berg', 'colonialism', 'forrest', 'skateboard', 'xtc', 'claire', 'mariah', 'horton', 'fifties', 'mccoist', 'lillard', 'komediant', 'occurrences', 'philosophically', 'maggio', 'unseen', 'latino', 'hyang', 'digressions', 'photographer', 'cutthroat', 'byplay', 'appétit', 'mar', 'campion', 'colosseum', 'camps', 'ces', 'invaders', 'forever', 'monroe', 'remade', 'spree', 'cadavers', 'burke', 'kilted', 'efteriades', 'recreated', '1972', 'overburdened', 'pelosi', 'conforms', 'fraser', 'lux', 'hanky', 'pad', 'sallies', 'depends', 'parris', 'lantern', 'grenier', 'xiaoshuai', 'staggering', 'shunji', 'nostra', '51st', 'kirshner', 'treacle', 'hawley', 'assailants', 'uwe', 'ballast', 'jeopardy', 'shohei', 'epps', 'cortez', 'giler', '270', 'kiarostami', 'cockeyed', 'jelinek', 'riviera', 'talkers', 'christine', 'hem', 'zeus', 'automatic', 'ark', 'loops', 'hutchins', 'observer', 'sonnenfeld', 'fisk', 'veggietales', 'patric', 'sontag', 'novelist', 'cornpone', 'lovebirds', 'coast', 'fatale', 'fulford', 'shankman', 'mccracken', 'justine', 'convinces', 'voyeur', 'v', 'flatman', 'methodical', 'tomfoolery', 'fanatic', 'review', 'victor', 'friedman', 'o2', 'applegate', 'sabara', 'wes', 'limb', 'mcadams', 'campbell', 'ancillary', 'rymer', 'minus', 'bickering', 'anarchic', 'foo', 'greg', 'kidlets', 'completists', 'peekaboo', 'expeditious', 'statham', 'citizen', 'hatosy', 'orc', 'um', 'antagonism', 'ackerman', 'stortelling', 'moretti', 'greaseballs', 'spaniel', 'girardot', 'gears', 'locale', 'animé', 'macgraw', 'rehearsals', 'casualties', 'guises', 'starship', 'cleanflicks', 'civilized', 'rosa', 'panky', 'lipstick', 'westbrook', 'watches', 'representing', 'bursting', 'ismail', 'hobby', 'unders', 'fangoria', 'turturro', 'fistfights', 'kangaroo', 'uruk', 'plumbed', 'fairlane', 'jaglomized', 'khouri', 'products', 'cusack', 'featherweight', 'juni', 'beside', 'carey', 'underlined', 'zoom', 'bratt', 'hunnam', 'broder', 'gump', 'charly', 'eun', 'chirpy', 'otto', 'unexamined', 'bluto', 'dances', 'float', 'gayton', 'resides', 'counterpart', 'masala', 'bros', 'spotlights', 'unfurls', 'deepa', 'mantra', 'imogen', 'glance', 'hai', 'lookin', 'steadfastly', 'vera', 'planned', 'zaza', 'portugal', 'rogers', 'explanations', 'blutarsky', 'assimilated', 'athletic', 'chop', 'seigner', 'thulani', 'yung', 'vereté', 'stern', 'coburn', 'chalk', 'lately', 'stalked', 'romething', 'annual', 'folktales', 'andré', '4w', 'tolstoy', 'riddles', 'barbers', 'granger', 'summary', 'parlance', 'began', '37', 'spiderman', 'grooved', 'hoult', 'boyd', 'groupies', 'femme', 'contraption', 'thi', 'pandemonium', 'skateboards', 'puportedly', 'beresford', 'cirulnick', 'shellshock', 'snoots', 'mounts', 'ken', 'seriocomic', 'artnering', 'winged', 'breen', 'cristo', 'theorizing', 'simpsons', 'edmund', 'impetuousness', 'underwater', 'colgate', 'galinsky', 'falsehoods', 'ascertain', 'blisteringly', 'hinge', 'zealously', 'visualizing', 'instalment', 'ward', 'cineasts', 'synthetic', 'uzumaki', 'munch', 'evoke', 'rail', 'tres', 'eternally', 'strongman', 'cook', 'gushy', 'egoyan', 'josé', 'boyz', 'doodled', 'halos', 'mai', 'elie', 'surviving', 'diapers', 'bogdanich', 'suey', 'overload', 'threshold', 'dynamite', 'aiming', 'forgivable', 'transgression', 'aan', 'scan', 'dafoe', 'schweig', 'concubine', 'tunis', 'hems', 'symbolically', 'polson', 'findings', 'heidi', 'culled', 'sweep', 'unrequited', 'diversions', 'bailly', 'commercials', 'rudy', 'breillat', 'sunday', 'spade', 'judging', 'hovering', 'janszen', 'brett', 'judith', 'slc', 'ub', 'drowning', 'fertility', 'alfonso', 'calculations', 'escapades', 'dewy', 'bart', '15th', 'wierzbicki', 'gunfest', 'slips', 'unconned', 'koshashvili', 'cuarón', 'tightly', 'swirl', 'spectators', 'perpetrated', 'characterisation', 'interpersonal', '1979 ...

# %%
# Select sentences that contain rare words
preservation_set = []
for label, sentence in tokenized_data:
    if any(word in rare_words for word in sentence):
        preservation_set.append((label, " ".join(sentence)))

# Print the selected sentences
print("\nPreservation Set:")
for label, sentence in preservation_set:
    print(f"Label: {label}, Sentence: {sentence}")
# Out:
# Preservation Set:
# Label: 1, Sentence: if anything see it for karen black who camps up a storm as a fringe feminist conspiracy theorist named dirty dick
# Label: 0, Sentence: poor ben bratt could n t find stardom if mapquest emailed him point to point driving directions
# Label: 1, Sentence: khouri manages with terrific flair to keep the extremes of screwball farce and blood curdling family intensity on one continuum
# Label: 0, Sentence: nicks and steinberg match their own creations for pure venality that s giving it the old college try
# Label: 1, Sentence: the picture runs a mere 84 minutes but it s no glance
# Label: 1, Sentence: ub equally spoofs and celebrates the more outre aspects of black culture and the dorkier aspects of white culture even as it points out how inseparable the two are
# Label: 0, Sentence: an already thin story boils down to surviving invaders seeking an existent anti virus
# Label: 1, Sentence: those eternally devoted to the insanity of black will have an intermittently good time
# Label: 0, Sentence: kirshner and monroe seem to be in a contest to see who can out bad act the other
# Label: 0, Sentence: do we really need the tiger beat version
# Label: 0, Sentence: as underwater ghost stories go below casts its spooky net out into the atlantic ocean and spits it back grizzled and charred somewhere northwest of the bermuda triangle
# Label: 0, Sentence: haneke s script from elfriede jelinek s novel is contrived unmotivated and psychologically unpersuasive with an inconclusive ending
# Label: 1, Sentence: the moral shrapnel and mental shellshock will linger long after this film has ended
# Label: 0, Sentence: falsehoods pile up undermining the movie s reality and stifling its creator s comic voice
# Label: 1, Sentence: director paul cox s unorthodox abstract approach to visualizing nijinsky s diaries is both stimulating and demanding
# Label: 0, Sentence: the emotional overload of female angst irreparably drags the film down
# Label: 1, Sentence: judging by those standards scratch is a pretty decent little documentary
# Label: 0, Sentence: a sugar coated rocky whose valuable messages are forgotten 10 minutes after the last trombone honks
# Label: 1, Sentence: spiderman rocks
# Label: 1, Sentence: campbell scott finds the ideal outlet for his flick knife diction in the role of roger swanson
# Label: 1, Sentence: smaller numbered kidlets will enjoy
# Label: 1, Sentence: vereté has a whip smart sense of narrative bluffs
# Label: 1, Sentence: the byplay and bickering between the now spy savvy siblings carmen vega and juni sabara cortez anchor the film in a very real and amusing give and take
# Label: 0, Sentence: forages for audience sympathy like a temperamental child begging for attention giving audiences no reason to truly care for its decrepit freaks beyond the promise of a reprieve from their incessant whining
# Label: 1, Sentence: rogers s mouth never stops shut about the war between the sexes and how to win the battle
# Label: 1, Sentence: the sight of the spaceship on the launching pad is duly impressive in imax dimensions as are shots of the astronauts floating in their cabins
# Label: 0, Sentence: a horror movie with seriously dumb characters which somewhat dilutes the pleasure of watching them stalked by creepy crawly bug things that live only in the darkness
# Label: 0, Sentence: a sluggish pace and lack of genuine narrative hem the movie in every bit as much as life hems in the spirits of these young women
# Label: 1, Sentence: one of the most important and exhilarating forms of animated filmmaking since old walt doodled steamboat willie
# Label: 0, Sentence: constantly slips from the grasp of its maker
# Label: 1, Sentence: there s a sheer unbridled delight in the way the story unfurls
# Label: 0, Sentence: brainless but enjoyably over the top the retro gang melodrama deuces wild represents fifties teen gang machismo in a way that borders on rough trade homo eroticism
# Label: 1, Sentence: jacquot s strategy allows his cast the benefit of being able to give full performances while demonstrating vividly that the beauty and power of the opera reside primarily in the music itself
# Label: 1, Sentence: cusack s just brilliant in this
# Label: 0, Sentence: this story of unrequited love does n t sustain interest beyond the first half hour
# Label: 0, Sentence: overburdened with complicated plotting and banal dialogue
# Label: 1, Sentence: efteriades gives the neighborhood scenery vibe and all the cinematic equivalent of a big tender hug
# Label: 1, Sentence: both grant and hoult carry the movie because they are believable as people flawed assured of the wrong things and scared to admit how much they may really need the company of others
# Label: 1, Sentence: with a large cast representing a broad cross section tavernier s film bounds along with the rat a tat energy of his girl friday maintaining a light touch while tackling serious themes
# Label: 0, Sentence: a movie where story is almost an afterthought amidst a swirl of colors and inexplicable events
# Label: 0, Sentence: writer director walter hill and co writer david giler try to create characters out of the obvious cliches but wind up using them as punching bags
# Label: 0, Sentence: if the title is a jeopardy question then the answer might be how does steven seagal come across these days
# Label: 0, Sentence: made to be jaglomized is the cannes film festival the annual riviera spree of flesh buzz blab and money
# Label: 1, Sentence: westbrook makes a wonderful subject for the camera
# Label: 1, Sentence: sitting in the third row of the imax cinema at sydney s darling harbour but i sometimes felt as though i was in the tiny two seater plane that carried the giant camera around australia sweeping and gliding banking and hovering over some of the most not
# Label: 0, Sentence: borstal boy represents the worst kind of filmmaking the kind that pretends to be passionate and truthful but is really frustratingly timid and soggy
# Label: 0, Sentence: in the process of trimming the movie to an expeditious 84 minutes director roger kumble seems to have dumped a whole lot of plot in favor of outrageous gags
# Label: 1, Sentence: the most brilliant work in this genre since the 1984 uncut version of sergio leone s flawed but staggering once upon a time in america
# Label: 1, Sentence: as comedic spotlights go notorious c h o hits all the verbal marks it should
# Label: 0, Sentence: the april 2002 instalment of the american war for independence complete with loads of cgi and bushels of violence but not a drop of human blood
# Label: 1, Sentence: australian filmmaker david flatman uses the huge screen format to make an old fashioned nature film that educates viewers with words and pictures while entertaining them
# Label: 0, Sentence: not a strike against yang s similarly themed yi yi but i found what time
# Label: 0, Sentence: written flatly by david kendall and directed barely by there s something about mary co writer ed decter
# Label: 0, Sentence: in old fashioned screenwriting parlance ms shreve s novel proved too difficult a text to lick despite the efforts of a first rate cast
# Label: 1, Sentence: west coast rap wars this modern mob music drama never fails to fascinate
# Label: 0, Sentence: rymer does n t trust laughs and does n t conjure proper respect for followers of the whole dead undead genre who deserve more from a vampire pic than a few shrieky special effects
# Label: 0, Sentence: swinging the film makes it seem is not a hobby that attracts the young and fit
# Label: 1, Sentence: allen s best works understand why snobbery is a better satiric target than middle america diversions could ever be
# Label: 0, Sentence: wes craven s presence is felt not the craven of a nightmare on elm street or the hills have eyes but the sad schlock merchant of deadly friend
# Label: 1, Sentence: jason patric and ray liotta make for one splendidly cast pair
# Label: 1, Sentence: absorbing character study by andré turpin
# Label: 1, Sentence: griffin co manage to be spectacularly outrageous
# Label: 1, Sentence: i ll go out on a limb
# Label: 1, Sentence: like all of egoyan s work ararat is fiercely intelligent and uncommonly ambitious
# Label: 1, Sentence: otto sallies has a real filmmaker s eye
# Label: 0, Sentence: a rude black comedy about the catalytic effect a holy fool has upon those around him in the cutthroat world of children s television
# Label: 1, Sentence: vera has created a provocative absorbing drama that reveals the curse of a self hatred instilled by rigid social mores
# Label: 1, Sentence: a weird little movie that s amusing enough while you watch it offering fine acting moments and pungent insights into modern l a s show biz and media subcultures
# Label: 0, Sentence: conforms itself with creating a game of who s who where the characters moves are often more predictable than their consequences
# Label: 0, Sentence: the film s needlessly opaque intro takes its doe eyed crudup out of pre 9 11 new york and onto a cross country road trip of the homeric kind
# Label: 0, Sentence: comes alive only when it switches gears to the sentimental
# Label: 0, Sentence: spectators will indeed sit open mouthed before the screen not screaming but yawning
# Label: 0, Sentence: whatever satire lucky break was aiming for it certainly got lost in the soon to be forgettable section of the quirky rip off prison romp pile
# Label: 0, Sentence: like a pack of dynamite sticks built for controversy
# Label: 1, Sentence: a gently funny sweetly adventurous film that makes you feel genuinely good that is to say entirely unconned by false sentiment or sharp overmanipulative hollywood practices
# Label: 0, Sentence: greaseballs mob action comedy
# Label: 1, Sentence: it s sort of a 21st century morality play with a latino hip hop beat
# Label: 1, Sentence: wang xiaoshuai directs this intricately structured and well realized drama that presents a fascinating glimpse of urban life and the class warfare that embroils two young men
# Label: 1, Sentence: strange occurrences build in the mind of the viewer and take on extreme urgency
# Label: 1, Sentence: victor rosa is leguizamo s best movie work so far a subtle and richly internalized performance
# Label: 0, Sentence: drowning s too good for this sucker
# Label: 1, Sentence: it is an unstinting look at a collaboration between damaged people that may or may not qual
# Label: 0, Sentence: aspires to the cracked lunacy of the adventures of buckaroo banzai but thanks to an astonishingly witless script ends up more like the adventures of ford fairlane
# Label: 1, Sentence: though writer director bart freundlich s film ultimately becomes a simplistic story about a dysfunctional parent child relationship it has some special qualities and the soulful gravity of crudup s anchoring performance
# Label: 1, Sentence: any enjoyment will be hinge from a personal threshold of watching sad but endearing characters do extremely unconventional things
# Label: 1, Sentence: maggie smith as the ya ya member with the o2 tank will absolutely crack you up with her crass then gasp for gas verbal deportment
# Label: 1, Sentence: delia greta and paula rank as three of the most multilayered and sympathetic female characters of the year
# Label: 0, Sentence: even when crush departs from the 4w formula it feels like a glossy rehash
# Label: 0, Sentence: adroit but finally a trifle flat mad love does n t galvanize its outrage the way say jane campion might have done but at least it possesses some
# Label: 0, Sentence: bogdanich is unashamedly pro serbian and makes little attempt to give voice to the other side
# Label: 1, Sentence: hatosy portrays young brendan with his usual intelligence and subtlety not to mention a convincing brogue
# Label: 1, Sentence: director chris wedge and screenwriters michael berg michael j wilson and peter ackerman create some episodes that rival vintage looney tunes for the most creative mayhem in a brief amount of time
# Label: 1, Sentence: monte cristo smartly emphasizes the well wrought story and omits needless chase scenes and swordfights as the revenge unfolds
# Label: 0, Sentence: this 90 minute dud could pass for mike tyson s e
# Label: 1, Sentence: if you have n t seen the film lately you may be surprised at the variety of tones in spielberg s work
# Label: 0, Sentence: breen s script is sketchy with actorish notations on the margin of acting
# Label: 1, Sentence: bon appétit
# Label: 0, Sentence: director uwe boll and writer robert dean klein fail to generate any interest in an unsympathetic hero caught up in an intricate plot that while cleverly worked out can not overcome blah characters
# Label: 1, Sentence: robert john burke as the monster horns in and steals the show
# Label: 0, Sentence: what s worse is that pelosi knows it
# Label: 1, Sentence: smarter than its commercials make it seem
# Label: 0, Sentence: it s hard to say who might enjoy this are there tolstoy groupies out there
# Label: 1, Sentence: the film tackles the topic of relationships in such a straightforward emotionally honest manner that by the end it s impossible to ascertain whether the film is at its core deeply pessimistic or quietly hopeful
# Label: 1, Sentence: steadfastly uncinematic but powerfully dramatic
# Label: 0, Sentence: director elie chouraqui who co wrote the script catches the chaotic horror of war but why bother if you re going to subjugate truth to the tear jerking demands of soap opera
# Label: 0, Sentence: well in some of those the mother deer even dies
# Label: 1, Sentence: the sentimental cliches mar an otherwise excellent film
# Label: 1, Sentence: makes one thing abundantly clear
# Label: 0, Sentence: a summary of the plot does n t quite do justice to the awfulness of the movie for that comes through all too painfully in the execution
# Label: 0, Sentence: femme fatale offers nothing more than a bait and switch that is beyond playing fair with the audience
# Label: 0, Sentence: the mantra behind the project seems to have been it s just a kids flick
# Label: 0, Sentence: the film s final hour where nearly all the previous unseen material resides is unconvincing soap opera that tornatore was right to cut
# Label: 1, Sentence: thirteen conversations about one thing lays out a narrative puzzle that interweaves individual stories and like a mobius strip elliptically loops back to where it began
# Label: 0, Sentence: overall tomfoolery like this is a matter of taste
# Label: 1, Sentence: though in some ways similar to catherine breillat s fat girl rain is the far superior film
# Label: 0, Sentence: it s not an easy one to review
# Label: 1, Sentence: matthew lillard is born to play shaggy
# Label: 1, Sentence: as antonia is assimilated into this newfangled community the film settles in and becomes compulsively watchable in a guilty pleasure daytime drama sort of fashion
# Label: 0, Sentence: um is n t that the basis for the entire plot
# Label: 0, Sentence: snoots will no doubt rally to its cause trotting out threadbare standbys like masterpiece and triumph and all that malarkey but rarely does an established filmmaker so ardently waste viewers time with a gobbler like this
# Label: 0, Sentence: statham employs an accent that i think is supposed to be an attempt at hardass american but sometimes just lapses into unhidden british
# Label: 0, Sentence: the colorful masseur wastes its time on mood rather than riding with the inherent absurdity of ganesh s rise up the social ladder
# Label: 1, Sentence: breheny s lensing of the new zealand and cook island locations captures both the beauty of the land and the people
# Label: 0, Sentence: aan opportunity wasted
# Label: 0, Sentence: zigzag might have been richer and more observant if it were less densely plotted
# Label: 0, Sentence: uzumaki s interesting social parallel and defiant aesthetic seems a prostituted muse
# Label: 1, Sentence: grenier is terrific bringing an unforced rapid fire delivery to toback s heidegger and nietzsche referencing dialogue
# Label: 0, Sentence: watching a brian depalma movie is like watching an alfred hitchcock movie after drinking twelve beers
# Label: 0, Sentence: despite all the closed door hanky panky the film is essentially juiceless
# Label: 0, Sentence: shunji iwai s all about lily chou chou is a beautifully shot but ultimately flawed film about growing up in japan
# Label: 0, Sentence: the modern day royals have nothing on these guys when it comes to scandals
# Label: 0, Sentence: with the exception of mccoist the players do n t have a clue on the park
# Label: 0, Sentence: the movie s vision of a white american zealously spreading a puritanical brand of christianity to south seas islanders is one only a true believer could relish
# Label: 0, Sentence: incoherence reigns
# Label: 0, Sentence: suffice to say its total promise is left slightly unfulfilled
# Label: 1, Sentence: a film of delicate interpersonal dances
# Label: 0, Sentence: a series of escapades demonstrating the adage that what is good for the goose is also good for the gander some of which occasionally amuses but none of which amounts to much of a story
# Label: 1, Sentence: caviezel embodies the transformation of his character completely
# Label: 1, Sentence: spectacular in every sense of the word even if you don t know an orc from a uruk hai
# Label: 1, Sentence: land people and narrative flow together in a stark portrait of motherhood deferred and desire explored
# Label: 0, Sentence: to the civilized mind a movie like ballistic ecks vs sever is more of an ordeal than an amusement
# Label: 0, Sentence: those 24 and unders looking for their own caddyshack to adopt as a generational signpost may have to keep on looking
# Label: 1, Sentence: katz s documentary does n t have much panache but with material this rich it does n t need it
# Label: 0, Sentence: this dreadfully earnest inversion of the concubine love triangle eschews the previous film s historical panorama and roiling pathos for bug eyed mugging and gay niche condescension
# Label: 0, Sentence: the heedless impetuousness of youth is on full irritating display in this meandering and pointless french coming of age import from writer director anne sophie birot
# Label: 1, Sentence: cineasts will revel in those visual in jokes as in the film s verbal pokes at everything from the likes of miramax chief harvey weinstein s bluff personal style to the stylistic rigors of denmark s dogma movement
# Label: 0, Sentence: plays like one of those conversations that comic book guy on the simpsons has
# Label: 0, Sentence: the screenplay by james eric james horton and director peter o fallon is so pat it makes your teeth hurt
# Label: 1, Sentence: bluto blutarsky we miss you
# Label: 0, Sentence: a retread of material already thoroughly plumbed by martin scorsese
# Label: 0, Sentence: a gushy episode of m a s h only this time from an asian perspective
# Label: 0, Sentence: pascale bailly s rom com provides amélie s audrey tautou with another fabuleux destin i e a banal spiritual quest
# Label: 1, Sentence: you walk out of the good girl with mixed emotions disapproval of justine combined with a tinge of understanding for her actions
# Label: 0, Sentence: boyd s screenplay co written with guardian hack nick davies has a florid turn of phrase that owes more to guy ritchie than the bard of avon
# Label: 1, Sentence: a tone poem of transgression
# Label: 1, Sentence: even if you ve seen stomp the stage show you still have to see this
# Label: 1, Sentence: the slam bang superheroics are kinetic enough to engross even the most antsy youngsters
# Label: 0, Sentence: no cliche escapes the perfervid treatment of gang warfare called ces wild
# Label: 0, Sentence: with the dog days of august upon us think of this dog of a movie as the cinematic equivalent of high humidity
# Label: 0, Sentence: typical animé with cheapo animation like saturday morning tv in the 60s a complex sword and sorcery plot and characters who all have big round eyes and japanese names
# Label: 1, Sentence: how good this film might be depends if you believe that the shocking conclusion is too much of a plunge or not
# Label: 1, Sentence: he watches them as they float within the seas of their personalities
# Label: 1, Sentence: ou ve got to love a disney pic with as little cleavage as this one has and a heroine as feisty and principled as jane
# Label: 1, Sentence: the spaniel eyed jean reno infuses hubert with a mixture of deadpan cool wry humor and just the measure of tenderness required to give this comic slugfest some heart
# Label: 0, Sentence: instead of panoramic sweep kapur gives us episodic choppiness undermining the story s emotional thrust
# Label: 1, Sentence: claire is a terrific role for someone like judd who really ought to be playing villains
# Label: 1, Sentence: niccol the filmmaker merges his collaborators symbolic images with his words insinuating for example that in hollywood only god speaks to the press
# Label: 1, Sentence: parris performance is credible and remarkably mature
# Label: 1, Sentence: a moving tale of love and destruction in unexpected places unexamined lives
# Label: 1, Sentence: offers a persuasive look at a defeated but defiant nation in flux
# Label: 1, Sentence: the powder blues and sun splashed whites of tunis make an alluring backdrop for this sensuous and spirited tale of a prim widow who finds an unlikely release in belly dancing clubs
# Label: 0, Sentence: broder s screenplay is shallow offensive and redundant with pitifully few real laughs
# Label: 0, Sentence: will anyone who is n t a fangoria subscriber be excited that it has n t gone straight to video
# Label: 1, Sentence: a directorial tour de force by bernard rose ivans xtc
# Label: 1, Sentence: kids who are into this thornberry stuff will probably be in wedgie heaven
# Label: 1, Sentence: jeff s gorgeous fluid compositions underlined by neil finn and edmund mcwilliams s melancholy music are charged with metaphor but rarely easy obvious or self indulgent
# Label: 0, Sentence: this dubious product of a college spawned colgate u comedy ensemble known as broken lizard plays like a mix of cheech and chong and chips
# Label: 0, Sentence: no amount of blood and disintegrating vampire cadavers can obscure this movie s lack of ideas
# Label: 0, Sentence: even a hardened voyeur would require the patience of job to get through this interminable shapeless documentary about the swinging subculture
# Label: 1, Sentence: director alfonso cuaron gets vivid convincing performances from a fine cast and generally keeps things going at a rapid pace occasionally using an omniscient voice over narrator in the manner of french new wave films
# Label: 0, Sentence: it s one thing to read about or rail against the ongoing and unprecedented construction project going on over our heads
# Label: 1, Sentence: on the granger movie gauge of 1 to 10 the powerpuff girls is a fast frenetic funny even punny 6 aimed specifically at a grade school audience
# Label: 1, Sentence: ken russell would love this
# Label: 0, Sentence: the advantage of a postapocalyptic setting is that it can be made on the cheap
# Label: 0, Sentence: a cross between blow and boyz n the hood this movie strives to be more but does n t quite get there
# Label: 0, Sentence: shankman and screenwriter karen janszen bungle their way through the narrative as if it were a series of bible parables and not an actual story
# Label: 1, Sentence: watching war photographer you come to believe that nachtwey hates the wars he shows and empathizes with the victims he reveals
# Label: 0, Sentence: is significantly less charming than listening to a four year old with a taste for exaggeration recount his halloween trip to the haunted house
# Label: 1, Sentence: p artnering murphy with robert de niro for the tv cops comedy showtime would seem to be surefire casting
# Label: 0, Sentence: a word of advice to the makers of the singles ward celebrity cameos do not automatically equal laughs
# Label: 1, Sentence: a tightly directed highly professional film that s old fashioned in all the best possible ways
# Label: 0, Sentence: unwieldy contraption
# Label: 0, Sentence: unless bob crane is someone of particular interest to you this film s impressive performances and adept direction are n t likely to leave a lasting impression
# Label: 0, Sentence: essentially fatal attraction remade for viewers who were in diapers when the original was released in 1987
# Label: 1, Sentence: special p o v camera mounts on bikes skateboards and motorcycles provide an intense experience when splashed across the immense imax screen
# Label: 1, Sentence: with amazing finesse the film shadows heidi s trip back to vietnam and the city where her mother mai thi kim still lives
# Label: 1, Sentence: with the prospect of films like kangaroo jack about to burst across america s winter movie screens it s a pleasure to have a film like the hours as an alternative
# Label: 0, Sentence: if you recognize zeus the dog from snatch it will make you wish you were at home watching that movie instead of in the theater watching this one
# Label: 1, Sentence: bursting through the constraints of its source this is one adapted from television movie that actually looks as if it belongs on the big screen
# Label: 1, Sentence: its almost too spectacular coastal setting distracts slightly from an eccentric and good naturedly aimless story
# Label: 0, Sentence: a bland obnoxious 88 minute infomercial for universal studios and its ancillary products
# Label: 1, Sentence: when cowering and begging at the feet a scruffy giannini madonna gives her best performance since abel ferrara had her beaten to a pulp in his dangerous game
# Label: 1, Sentence: some of the most ravaging gut wrenching frightening war scenes since saving private ryan have been recreated by john woo in this little known story of native americans and their role in the second great war
# Label: 0, Sentence: with its paint fights motorized scooter chases and dewy eyed sentiment it s a pretty listless collection of kid movie clichés
# Label: 0, Sentence: officially it is twice as bestial but half as funny
# Label: 0, Sentence: even fans of ismail merchant s work i suspect would have a hard time sitting through this one
# Label: 1, Sentence: even the digressions are funny
# Label: 1, Sentence: certainly the big finish was n t something galinsky and hawley could have planned for but part of being a good documentarian is being there when the rope snaps
# Label: 1, Sentence: as giddy and whimsical and relevant today as it was 270 years ago
# Label: 1, Sentence: an often watchable though goofy and lurid blast of a costume drama set in the late 15th century
# Label: 0, Sentence: with or without ballast tanks k 19 sinks to a harrison ford low
# Label: 0, Sentence: chalk it up as the worst kind of hubristic folly
# Label: 0, Sentence: unless you re a fanatic the best advice is scooby do n t
# Label: 0, Sentence: the skirmishes for power waged among victims and predators settle into an undistinguished rhythm of artificial suspense
# Label: 1, Sentence: eric schweig and graham greene both exude an air of dignity that s perfect for the proud warrior that still lingers in the souls of these characters
# Label: 1, Sentence: jae eun jeong s take care of my cat brings a beguiling freshness to a coming of age story with such a buoyant expressive flow of images that it emerges as another key contribution to the flowering of the south korean cinema
# Label: 0, Sentence: a listless sci fi comedy in which eddie murphy deploys two guises and elaborate futuristic sets to no particularly memorable effect
# Label: 0, Sentence: more a gunfest than a rock concert
# Label: 1, Sentence: young hanks and fisk who vaguely resemble their celebrity parents bring fresh good looks and an ease in front of the camera to the work
# Label: 1, Sentence: it s neither as sappy as big daddy nor as anarchic as happy gilmore or the waterboy but it has its moments
# Label: 1, Sentence: rehearsals are frequently more fascinating than the results
# Label: 0, Sentence: that chirpy songbird britney spears has popped up with more mindless drivel
# Label: 1, Sentence: mariah carey gives us another peek at some of the magic we saw in glitter here in wisegirls
# Label: 0, Sentence: the locale remains far more interesting than the story at hand
# Label: 0, Sentence: neither as scary funny as tremors nor demented funny as starship troopers the movie is n t tough to take as long as you ve paid a matinee price
# Label: 0, Sentence: a disaster of a drama saved only by its winged assailants
# Label: 1, Sentence: scott baio is turning in some delightful work on indie projects
# Label: 1, Sentence: dark and unrepentant this excursion into the epicenter of percolating mental instability is not easily dismissed or forgotten
# Label: 0, Sentence: leaks treacle from every pore
# Label: 0, Sentence: lazily directed by charles stone iii from a leaden script by matthew cirulnick and novelist thulani davis
# Label: 0, Sentence: an authentically vague but ultimately purposeless study in total pandemonium
# Label: 1, Sentence: gayton s script telegraphs every discovery and layers on the gloss of convenience
# Label: 1, Sentence: d espite its familiar subject matter ice age is consistently amusing and engrossing
# Label: 0, Sentence: perhaps even the slc high command found writer director mitch davis s wall of kitsch hard going
# Label: 0, Sentence: like rudy yellow lodge eyre needs to take a good sweat to clarify his cinematic vision before his next creation and remember the lessons of the trickster spider
# Label: 0, Sentence: every conceivable mistake a director could make in filming opera has been perpetrated here
# Label: 1, Sentence: the little girls understand and mccracken knows that s all that matters
# Label: 1, Sentence: a moving and solidly entertaining comedy drama that should bolster director and co writer juan josé campanella s reputation in the united states
# Label: 1, Sentence: a tasty masala
# Label: 1, Sentence: fulford wierzbicki deftly captures the wise beyond her years teen
# Label: 0, Sentence: imagine susan sontag falling in love with howard stern
# Label: 0, Sentence: a kilted jackson is an unsettling sight and indicative of his if you will out of kilter character who rambles aimlessly through ill conceived action pieces
# Label: 0, Sentence: the 50 something lovebirds are too immature and unappealing to care about
# Label: 1, Sentence: ms hutchins is talented enough and charismatic enough to make us care about zelda s ultimate fate
# Label: 1, Sentence: nakata s technique is to imply terror by suggestion rather than the overuse of special effects
# Label: 0, Sentence: there is something in full frontal i guess about artifice and acting and how it distorts reality for people who make movies and watch them but like most movie riddles it works only if you have an interest in the characters you see
# Label: 1, Sentence: mr caine and mr fraser are the whole show here with their memorable and resourceful performances
# Label: 1, Sentence: a much more successful translation than its most famous previous film adaptation writer director anthony friedman s similarly updated 1970 british production
# Label: 1, Sentence: ms seigner and mr serrault bring fresh unforced naturalism to their characters
# Label: 1, Sentence: peppering this urban study with references to norwegian folktales villeneuve creates in maelstrom a world where the bizarre is credible and the real turns magical
# Label: 1, Sentence: blisteringly rude scarily funny sorrowfully sympathetic to the damage it surveys the film has in kieran culkin a pitch perfect holden
# Label: 0, Sentence: philosophically intellectually and logistically a mess
# Label: 0, Sentence: imagine the cleanflicks version of love story with ali macgraw s profanities replaced by romance novel platitudes
# Label: 1, Sentence: kinnear and dafoe give what may be the performances of their careers
# Label: 1, Sentence: in visual fertility treasure planet rivals the top japanese animations of recent vintage
# Label: 0, Sentence: a processed comedy chop suey
# Label: 1, Sentence: a moving and stark reminder that the casualties of war reach much further than we imagine
# Label: 1, Sentence: as part of mr dong s continuing exploration of homosexuality in america family fundamentals is an earnest study in despair
# Label: 0, Sentence: while the ensemble player who gained notice in guy ritchie s lock stock and two smoking barrels and snatch has the bod he s unlikely to become a household name on the basis of his first starring vehicle
# Label: 1, Sentence: mama africa pretty much delivers on that promise
# Label: 0, Sentence: characterisation has been sacrificed for the sake of spectacle
# Label: 1, Sentence: turturro is fabulously funny and over the top as a very sneaky butler who excels in the art of impossible disappearing reappearing acts
# Label: 1, Sentence: at 78 minutes it just zings along with vibrance and warmth
# Label: 1, Sentence: mazel tov to a film about a family s joyous life acting on the yiddish stage
# Label: 1, Sentence: a sentimental hybrid that could benefit from the spice of specificity
# Label: 1, Sentence: what does n t this film have that an impressionable kid could n t stand to hear
# Label: 0, Sentence: like a grinning jack o lantern its apparent glee is derived from a lobotomy having had all its vital essence scooped out and discarded
# Label: 1, Sentence: soderbergh skims the fat from the 1972 film
# Label: 1, Sentence: directors brett morgen and nanette burstein have put together a bold biographical fantasia
# Label: 0, Sentence: david spade as citizen kane
# Label: 0, Sentence: puportedly based on true events a convolution of language that suggests it s impossible to claim that it is based on a true story with a straight face
# Label: 1, Sentence: fear permeates the whole of stortelling todd solondz oftentimes funny yet ultimately cowardly autocritique
# Label: 0, Sentence: the most repugnant adaptation of a classic text since roland joffé and demi moore s the scarlet letter
# Label: 0, Sentence: what might have been acceptable on the printed page of iles book does not translate well to the screen
# Label: 1, Sentence: japanese director shohei imamura s latest film is an odd but ultimately satisfying blend of the sophomoric and the sublime
# Label: 1, Sentence: moretti is the rare common man artist who s wise enough to recognize that there are few things in this world more complex and as it turns out more fragile than happiness
# Label: 0, Sentence: the fact that it is n t very good is almost beside the point
# Label: 0, Sentence: a long dull procession of despair set to cello music culled from a minimalist funeral
# Label: 0, Sentence: while certainly more naturalistic than its australian counterpart amari s film falls short in building the drama of lilia s journey
# Label: 0, Sentence: all of the filmmakers calculations ca n t rescue brown sugar from the curse of blandness
# Label: 0, Sentence: real life strongman ahola lacks the charisma and ability to carry the film on his admittedly broad shoulders
# Label: 1, Sentence: diaz applegate blair and posey are suitably kooky which should appeal to women and they strip down often enough to keep men alert if not amused
# Label: 0, Sentence: the screenplay co written by director imogen kimmel lacks the wit necessary to fully exploit the comic elements of the premise making the proceedings more bizarre than actually amusing
# Label: 1, Sentence: foster and whitaker are especially fine
# Label: 1, Sentence: greg kinnear gives a mesmerizing performance as a full fledged sex addict who is in complete denial about his obsessive behavior
# Label: 1, Sentence: judith and zaza s extended bedroom sequence is so intimate and sensual and funny and psychologically self revealing that it makes most of what passes for sex in the movies look like cheap hysterics
# Label: 0, Sentence: it s better suited for the history or biography channel but there s no arguing the tone of the movie it leaves a bad taste in your mouth and questions on your mind
# Label: 1, Sentence: fortunately elling never gets too cloying thanks to the actors perfect comic timing and sweet genuine chemistry
# Label: 0, Sentence: in his role of observer of the scene lawrence sounds whiny and defensive as if his life altering experiences made him bitter and less mature
# Label: 0, Sentence: the holiday message of the 37 minute santa vs the snowman leaves a lot to be desired
# Label: 1, Sentence: cuarón has created a substantive movie out of several cliched movie structures the road movie the coming of age movie and the teenage sex comedy
# Label: 1, Sentence: tres greek writer and star nia vardalos has crafted here a worldly wise and very funny script
# Label: 0, Sentence: lookin for sin american style
# Label: 1, Sentence: delirious fun
# Label: 1, Sentence: russian ark is a new treasure of the hermitage
# Label: 1, Sentence: zoom
# Label: 1, Sentence: deepa mehta provides an accessible introduction as well as some intelligent observations on the success of bollywood in the western world
# Label: 0, Sentence: too bad maggio could n t come up with a better script
# Label: 1, Sentence: munch s screenplay is tenderly observant of his characters
# Label: 1, Sentence: barry convinces us he s a dangerous secretly unhinged guy who could easily have killed a president because it made him feel powerful
# Label: 1, Sentence: walter hill s undisputed is like a 1940s warner bros
# Label: 1, Sentence: the komediant is a tale worth catching
# Label: 1, Sentence: horns and halos benefits from serendipity but also reminds us of our own responsibility to question what is told as the truth
# Label: 1, Sentence: a pointed often tender examination of the pros and cons of unconditional love and familial duties
# Label: 0, Sentence: equlibrium could pass for a thirteen year old s book report on the totalitarian themes of 1984 and farenheit 451
# Label: 1, Sentence: like blended shades of lipstick these components combine into one terrific story with lots of laughs
# Label: 1, Sentence: kiarostami has crafted a deceptively casual ode to children and managed to convey a tiny sense of hope
# Label: 0, Sentence: charly comes off as emotionally manipulative and sadly imitative of innumerable past love story derisions
# Label: 1, Sentence: the most audacious outrageous sexually explicit psychologically probing pure libido film of the year has arrived from portugal
# Label: 1, Sentence: jeffs has created a breathtakingly assured and stylish work of spare dialogue and acute expressiveness
# Label: 1, Sentence: as the movie traces mr brown s athletic exploits it is impossible not to be awed by the power and grace of one of the greatest natural sportsmen of modern times
# Label: 1, Sentence: a wildly entertaining scan of evans career
# Label: 0, Sentence: the code talkers deserved better than a hollow tribute
# Label: 1, Sentence: a gracious eloquent film that by its end offers a ray of hope to the refugees able to look ahead and resist living in a past forever lost
# Label: 1, Sentence: most consumers of lo mein and general tso s chicken barely give a thought to the folks who prepare and deliver it so hopefully this film will attach a human face to all those little steaming cartons
# Label: 1, Sentence: australian actor director john polson and award winning english cinematographer giles nuttgens make a terrific effort at disguising the obvious with energy and innovation
# Label: 1, Sentence: when the movie mixes the cornpone and the cosa nostra it finds a nice rhythm
# Label: 1, Sentence: a delightful stimulus for the optic nerves so much that it s forgivable that the plot feels like every other tale of a totalitarian tomorrow
# Label: 0, Sentence: synthetic is the best description of this well meaning beautifully produced film that sacrifices its promise for a high powered star pedigree
# Label: 1, Sentence: hashiguchi uses the situation to evoke a japan bustling atop an undercurrent of loneliness and isolation
# Label: 0, Sentence: cloaks a familiar anti feminist equation career kids misery in tiresome romantic comedy duds
# Label: 0, Sentence: the movie spends more time with schneider than with newcomer mcadams even though her performance is more interesting and funnier than his
# Label: 1, Sentence: a seriocomic debut of extravagant promise by georgian israeli director dover kosashvili
# Label: 0, Sentence: romething s really wrong with this ricture
# Label: 1, Sentence: much has been written about those years when the psychedelic 60s grooved over into the gay 70s but words do n t really do the era justice
# Label: 0, Sentence: formulaic to the 51st power more like
# Label: 1, Sentence: a fresh entertaining comedy that looks at relationships minus traditional gender roles
# Label: 1, Sentence: the banter between calvin and his fellow barbers feels like a streetwise mclaughlin group and never fails to entertain
# Label: 0, Sentence: unless you come in to the film with a skateboard under your arm you re going to feel like you were n t invited to the party
# Label: 0, Sentence: clare peploe s airless movie adaptation could use a little american pie like irreverence
# Label: 1, Sentence: an encouraging effort from mccrudden
# Label: 1, Sentence: as averse as i usually am to feel good follow your dream hollywood fantasies this one got to me
# Label: 1, Sentence: as the dominant christine sylvie testud is icily brilliant
# Label: 1, Sentence: between bursts of automatic gunfire the story offers a trenchant critique of capitalism
# Label: 1, Sentence: yes that s right it s forrest gump angel of death
# Label: 0, Sentence: for dance completists only
# Label: 0, Sentence: nothing more than a stifling morality tale dressed up in peekaboo clothing
# Label: 0, Sentence: a cockeyed shot all the way
# Label: 0, Sentence: for all its shoot outs fistfights and car chases this movie is a phlegmatic bore so tedious it makes the silly spy vs spy film the sum of all fears starring ben affleck seem downright hitchcockian
# Label: 0, Sentence: one sided documentary offers simplistic explanations to a very complex situation
# Label: 0, Sentence: all the movie s narrative gymnastics ca n t disguise the fact that it s inauthentic at its core and that its story just is n t worth telling
# Label: 1, Sentence: charlie hunnam has the twinkling eyes repressed smile and determined face needed to carry out a dickensian hero
# Label: 1, Sentence: huppert and girardot give performances of exceptional honesty
# Label: 1, Sentence: lux now in her eighties does a great combination act as narrator jewish grandmother and subject taking us through a film that is part biography part entertainment and part history
# Label: 0, Sentence: a lightweight uneven action comedy that freely mingles french japanese and hollywood cultures
# Label: 0, Sentence: is n t it a bit early in his career for director barry sonnenfeld to do a homage to himself
# Label: 1, Sentence: one of the most splendid entertainments to emerge from the french film industry in years
# Label: 0, Sentence: epps has neither the charisma nor the natural affability that has made tucker a star
# Label: 1, Sentence: bloody sunday has the grace to call for prevention rather than to place blame making it one of the best war movies ever made
# Label: 1, Sentence: beresford nicely mixes in as much humor as pathos to take us on his sentimental journey of the heart
# Label: 0, Sentence: unlike trey parker sandler does n t understand that the idea of exploiting molestation for laughs is funny not actually exploiting it yourself
# Label: 1, Sentence: whether or not you buy mr broomfield s findings the film acquires an undeniable entertainment value as the slight pale mr broomfield continues to force himself on people and into situations that would make lesser men run for cover
# Label: 1, Sentence: graham greene s novel of colonialism and empire is elevated by michael caine s performance as a weary journalist in a changing world
# Label: 0, Sentence: the laughs are as rare as snake foo yung
# Label: 0, Sentence: gooding and coburn are both oscar winners a fact which as you watch them clumsily mugging their way through snow dogs seems inconceivable
# Label: 1, Sentence: for veggietales fans this is more appetizing than a side dish of asparagus
# Label: 1, Sentence: methodical measured and gently tedious in its comedy secret ballot is a purposefully reductive movie which may be why it s so successful at lodging itself in the brain
# Label: 1, Sentence: jeong hyang lee s film is deceptively simple deeply satisfying
# Label: 0, Sentence: no amount of arty theorizing the special effects are german expressionist according to the press notes can render it anything but laughable
# Label: 1, Sentence: definitely a crowd pleaser but then so was the roman colosseum
# Label: 1, Sentence: a gripping documentary that reveals how deep the antagonism lies in war torn jerusalem
# Label: 1, Sentence: featherweight romantic comedy has a few nice twists in a standard plot and the charisma of hugh grant and sandra bullock
# Label: 1, Sentence: mr koshashvili is a director to watch
# Label: 1, Sentence: symbolically warm water under a red bridge is a celebration of feminine energy a tribute to the power of women to heal
# Label: 1, Sentence: a quietly moving look back at what it was to be iranian american in 1979

# %%
# Save the preservation set to a text file
with open('sst2_preservation_set.txt', 'w', encoding='utf-8') as f:
    for label, sentence in preservation_set:
        f.write(f"{label}\t{sentence}\n")

print("Preservation set saved to 'sst2_preservation_set.txt'.")
# Out:
# Preservation set saved to 'sst2_preservation_set.txt'.
